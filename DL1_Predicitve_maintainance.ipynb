# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushiyaG14/Predictive_maintainence/blob/main/DL1_Predicitve_maintainance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/predictive_maintenance.csv")

# %%
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 0      No Failure
# 1      No Failure
# 2      No Failure
# 3      No Failure
# 4      No Failure
# ...           ...
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure
#
# [10000 rows x 10 columns]

# %%
df["Target"].value_counts()
# Out:
# Target
# 0    9661
# 1     339
# Name: count, dtype: int64

# %%
df["Type"].value_counts()
# Out:
# Type
# L    6000
# M    2997
# H    1003
# Name: count, dtype: int64

# %%
df["Failure Type"].value_counts()
# Out:
# Failure Type
# No Failure                  9652
# Heat Dissipation Failure     112
# Power Failure                 95
# Overstrain Failure            78
# Tool Wear Failure             45
# Random Failures               18
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Product ID"].nunique()
# Out:
# 10000

# %%
df.drop("UDI",axis=1,inplace=True)

# %%
df.drop("Target",axis=1,inplace=True)

# %%
df.set_index("Product ID",inplace=True)

# %%
df
# Out:
#            Type  Air temperature [K]  Process temperature [K]  \
# Product ID
# M14860        M                298.1                    308.6
# L47181        L                298.2                    308.7
# L47182        L                298.1                    308.5
# L47183        L                298.2                    308.6
# L47184        L                298.2                    308.7
# ...         ...                  ...                      ...
# M24855        M                298.8                    308.4
# H39410        H                298.9                    308.4
# M24857        M                299.0                    308.6
# H39412        H                299.0                    308.7
# M24859        M                299.0                    308.7
#
#             Rotational speed [rpm]  Torque [Nm]  Tool wear [min] Failure Type
# Product ID
# M14860                        1551         42.8                0   No Failure
# L47181                        1408         46.3                3   No Failure
# L47182                        1498         49.4                5   No Failure
# L47183                        1433         39.5                7   No Failure
# L47184                        1408         40.0                9   No Failure
# ...                            ...          ...              ...          ...
# M24855                        1604         29.5               14   No Failure
# H39410                        1632         31.8               17   No Failure
# M24857                        1645         33.4               22   No Failure
# H39412                        1408         48.5               25   No Failure
# M24859                        1500         40.2               30   No Failure
#
# [10000 rows x 7 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()

# %%
df['Type']=encoder.fit_transform(df[["Type"]])
df['Failure Type']=encoder.fit_transform(df[["Failure Type"]])

# %%
df
# Out:
#             Type  Air temperature [K]  Process temperature [K]  \
# Product ID
# M14860       2.0                298.1                    308.6
# L47181       1.0                298.2                    308.7
# L47182       1.0                298.1                    308.5
# L47183       1.0                298.2                    308.6
# L47184       1.0                298.2                    308.7
# ...          ...                  ...                      ...
# M24855       2.0                298.8                    308.4
# H39410       0.0                298.9                    308.4
# M24857       2.0                299.0                    308.6
# H39412       0.0                299.0                    308.7
# M24859       2.0                299.0                    308.7
#
#             Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Failure Type
# Product ID
# M14860                        1551         42.8                0           1.0
# L47181                        1408         46.3                3           1.0
# L47182                        1498         49.4                5           1.0
# L47183                        1433         39.5                7           1.0
# L47184                        1408         40.0                9           1.0
# ...                            ...          ...              ...           ...
# M24855                        1604         29.5               14           1.0
# H39410                        1632         31.8               17           1.0
# M24857                        1645         33.4               22           1.0
# H39412                        1408         48.5               25           1.0
# M24859                        1500         40.2               30           1.0
#
# [10000 rows x 7 columns]

# %%
df.corr()
# Out:
#                              Type  Air temperature [K]  \
# Type                     1.000000             0.017599
# Air temperature [K]      0.017599             1.000000
# Process temperature [K]  0.013444             0.876107
# Rotational speed [rpm]  -0.002693             0.022670
# Torque [Nm]              0.004011            -0.013778
# Tool wear [min]         -0.003930             0.013853
# Failure Type            -0.008249            -0.025327
#
#                          Process temperature [K]  Rotational speed [rpm]  \
# Type                                    0.013444               -0.002693
# Air temperature [K]                     0.876107                0.022670
# Process temperature [K]                 1.000000                0.019277
# Rotational speed [rpm]                  0.019277                1.000000
# Torque [Nm]                            -0.014061               -0.875027
# Tool wear [min]                         0.013488                0.000223
# Failure Type                           -0.004600                0.079407
#
#                          Torque [Nm]  Tool wear [min]  Failure Type
# Type                        0.004011        -0.003930     -0.008249
# Air temperature [K]        -0.013778         0.013853     -0.025327
# Process temperature [K]    -0.014061         0.013488     -0.004600
# Rotational speed [rpm]     -0.875027         0.000223      0.079407
# Torque [Nm]                 1.000000        -0.003093      0.031737
# Tool wear [min]            -0.003093         1.000000      0.111619
# Failure Type                0.031737         0.111619      1.000000

# %%
df.columns
# Out:
# Index(['Type', 'Air temperature [K]', 'Process temperature [K]',
#        'Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]',
#        'Failure Type'],
#       dtype='object')

# %%
#hypotheses

continues=['Air temperature [K]','Process temperature [K]','Rotational speed [rpm]', 'Torque [Nm]', 'Tool wear [min]']
categories=["Type","Target","Failure Type"]


from scipy import stats

def two_sample(d1,d2):
  t=0
  f=0
  for i in  range(31):
    sample1=d1.sample(frac=0.03)
    sample2=d2.sample(frac=0.03)
    t_test,p_value=stats.ttest_ind(sample1,sample2)
    if p_value < 0.055:
      f=f+1
    else:
      t=t+1
  if t>f:
    return True
  else:
    return False

#defining function for categories vs categories
def chisqare_cat_vs_cat(d1,d2):
  return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1] < 0.055 else False

def annova_test(d1,d2):
  group=df[d2].unique()
  data={}
  for i in group:
    data[i]=df[d1][df[d2]==i]
  f_value,p_value=stats.f_oneway(*[i for i in data.values()])  #task for baby
  if p_value < 0.055:
    return False
  else:
    return True

final={}
for i in df.columns:
  final[i]={}
  for j in df.columns:
    if (i in continues) and (j in continues):
      result=two_sample(df[i],df[j])
    elif  (i in continues) and (j in categories):
      result=annova_test(i,j)
    elif (i in categories) and (j in continues):
      result=annova_test(j,i)
    elif (i in categories) and (j in categories):
      result=chisqare_cat_vs_cat(df[i],df[j])
    if result:
      final[i][j]=1
    else:
      final[i][j]=0

# %%
df1=pd.DataFrame(final)

# %%
df1
# Out:
#                          Type  Air temperature [K]  Process temperature [K]  \
# Type                        1                    1                        1
# Air temperature [K]         1                    1                        0
# Process temperature [K]     1                    0                        1
# Rotational speed [rpm]      1                    0                        0
# Torque [Nm]                 1                    0                        0
# Tool wear [min]             1                    0                        0
# Failure Type                1                    0                        0
#
#                          Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  \
# Type                                          1            1                1
# Air temperature [K]                           0            0                0
# Process temperature [K]                       0            0                0
# Rotational speed [rpm]                        1            0                0
# Torque [Nm]                                   0            1                0
# Tool wear [min]                               0            0                1
# Failure Type                                  0            0                0
#
#                          Failure Type
# Type                                1
# Air temperature [K]                 0
# Process temperature [K]             0
# Rotational speed [rpm]              0
# Torque [Nm]                         0
# Tool wear [min]                     0
# Failure Type                        1

# %%
for i in continues:
    print(i,df[i].skew(),df[i].kurtosis())
# Out:
# Air temperature [K] 0.11427392052155042 -0.8359616725774668
# Process temperature [K] 0.015027267769228572 -0.4997343650161423
# Rotational speed [rpm] 1.9931710047137523 7.392944899246485
# Torque [Nm] -0.00951659584005855 -0.013240614017021368
# Tool wear [min] 0.027292239050452527 -1.1667371315780541

# %%
from scipy import stats
method=[0,0.5,-0.5,1,-1,2,-2]
for i in method:
      print(i)
      print("skewness",pd.DataFrame(stats.boxcox(df["Rotational speed [rpm]"],lmbda=i)).skew().values,"kurtosis",pd.DataFrame(stats.boxcox(df["Rotational speed [rpm]"],lmbda=i)).kurtosis().values)
print("--------------------------")
# Out:
# 0
# skewness [1.30936962] kurtosis [3.3358844]
# 0.5
# skewness [1.62440721] kurtosis [5.01580346]
# -0.5
# skewness [1.03725923] kurtosis [2.15747832]
# 1
# skewness [1.993171] kurtosis [7.3929449]
# -1
# skewness [0.79892159] kurtosis [1.33983664]
# 2
# skewness [2.9408124] kurtosis [15.36542039]
# -2
# skewness [0.] kurtosis [0.42249676]
# --------------------------

# %%
df['Rotational speed [rpm]']=stats.boxcox(df["Rotational speed [rpm]"],lmbda=-2)

# %%
df['Rotational speed [rpm]'].skew()
# Out:
# 0.0

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x=df.drop("Failure Type",axis=1)
y=df["Failure Type"]

# %%
from tensorflow.keras.utils import to_categorical
ynew=to_categorical(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,ynew,test_size=0.2)

# %%
scaler=StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_scaler=scaler.transform(x_train)

# %%
x_test_scaler=scaler.transform(x_test)

# %%
x_test_scaler=scaler.transform(x_test)

# %%
x_train_scaler.shape[1]
# Out:
# 6

# %%
import tensorflow as tf
dir(tf.keras.layers)
# Out:
# ['Activation',
#  'ActivityRegularization',
#  'Add',
#  'AdditiveAttention',
#  'AlphaDropout',
#  'Attention',
#  'Average',
#  'AveragePooling1D',
#  'AveragePooling2D',
#  'AveragePooling3D',
#  'AvgPool1D',
#  'AvgPool2D',
#  'AvgPool3D',
#  'BatchNormalization',
#  'Bidirectional',
#  'CategoryEncoding',
#  'CenterCrop',
#  'Concatenate',
#  'Conv1D',
#  'Conv1DTranspose',
#  'Conv2D',
#  'Conv2DTranspose',
#  'Conv3D',
#  'Conv3DTranspose',
#  'ConvLSTM1D',
#  'ConvLSTM2D',
#  'ConvLSTM3D',
#  'Convolution1D',
#  'Convolution1DTranspose',
#  'Convolution2D',
#  'Convolution2DTranspose',
#  'Convolution3D',
#  'Convolution3DTranspose',
#  'Cropping1D',
#  'Cropping2D',
#  'Cropping3D',
#  'Dense',
#  'DepthwiseConv1D',
#  'DepthwiseConv2D',
#  'Discretization',
#  'Dot',
#  'Dropout',
#  'ELU',
#  'EinsumDense',
#  'Embedding',
#  'Flatten',
#  'FlaxLayer',
#  'GRU',
#  'GRUCell',
#  'GaussianDropout',
#  'GaussianNoise',
#  'GlobalAveragePooling1D',
#  'GlobalAveragePooling2D',
#  'GlobalAveragePooling3D',
#  'GlobalAvgPool1D',
#  'GlobalAvgPool2D',
#  'GlobalAvgPool3D',
#  'GlobalMaxPool1D',
#  'GlobalMaxPool2D',
#  'GlobalMaxPool3D',
#  'GlobalMaxPooling1D',
#  'GlobalMaxPooling2D',
#  'GlobalMaxPooling3D',
#  'GroupNormalization',
#  'GroupQueryAttention',
#  'HashedCrossing',
#  'Hashing',
#  'Identity',
#  'Input',
#  'InputLayer',
#  'InputSpec',
#  'IntegerLookup',
#  'JaxLayer',
#  'LSTM',
#  'LSTMCell',
#  'Lambda',
#  'Layer',
#  'LayerNormalization',
#  'LeakyReLU',
#  'Masking',
#  'MaxPool1D',
#  'MaxPool2D',
#  'MaxPool3D',
#  'MaxPooling1D',
#  'MaxPooling2D',
#  'MaxPooling3D',
#  'Maximum',
#  'MelSpectrogram',
#  'Minimum',
#  'MultiHeadAttention',
#  'Multiply',
#  'Normalization',
#  'PReLU',
#  'Permute',
#  'RNN',
#  'RandomBrightness',
#  'RandomContrast',
#  'RandomCrop',
#  'RandomFlip',
#  'RandomHeight',
#  'RandomRotation',
#  'RandomTranslation',
#  'RandomWidth',
#  'RandomZoom',
#  'ReLU',
#  'RepeatVector',
#  'Rescaling',
#  'Reshape',
#  'Resizing',
#  'SeparableConv1D',
#  'SeparableConv2D',
#  'SeparableConvolution1D',
#  'SeparableConvolution2D',
#  'SimpleRNN',
#  'SimpleRNNCell',
#  'Softmax',
#  'SpatialDropout1D',
#  'SpatialDropout2D',
#  'SpatialDropout3D',
#  'SpectralNormalization',
#  'StackedRNNCells',
#  'StringLookup',
#  'Subtract',
#  'TFSMLayer',
#  'TextVectorization',
#  'ThresholdedReLU',
#  'TimeDistributed',
#  'TorchModuleWrapper',
#  'UnitNormalization',
#  'UpSampling1D',
#  'UpSampling2D',
#  'UpSampling3D',
#  'Wrapper',
#  'ZeroPadding1D',
#  'ZeroPadding2D',
#  'ZeroPadding3D',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'add',
#  'average',
#  'concatenate',
#  'deserialize',
#  'dot',
#  'maximum',
#  'minimum',
#  'multiply',
#  'serialize',
#  'subtract']

# %%
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential

import tensorflow as tf
model=Sequential()
model.add(Dense(1024,input_dim=x_train_scaler.shape[1],activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dropout(0.2))
model.add(Dense(512,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dropout(0.23))
model.add(Dense(256,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dropout(0.15))
model.add(Dense(64,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dense(32,activation=tf.keras.layers.LeakyReLU(alpha=0.2)))
model.add(Dense(6,activation="softmax"))
model.compile(loss="categorical_crossentropy",optimizer="adam",metrics=["accuracy",tf.keras.metrics.F1Score(),tf.keras.metrics.Recall(),tf.keras.metrics.Precision()])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 1024)                │           7,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 6)                   │             198 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 682,022 (2.60 MB)
#  Trainable params: 682,022 (2.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
x_train_scaler.shape
# Out:
# (8000, 6)

# %%
result=model.fit(x_train_scaler,y_train,epochs=20,validation_split=0.15,batch_size=16)#8000/15%
# Out:
# Epoch 1/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.9689 - f1_score: 0.3847 - loss: 0.1205 - precision_1: 0.9700 - recall_1: 0.9674 - val_accuracy: 0.9708 - val_f1_score: 0.3651 - val_loss: 0.1106 - val_precision_1: 0.9724 - val_recall_1: 0.9683
# Epoch 2/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9691 - f1_score: 0.4007 - loss: 0.1114 - precision_1: 0.9703 - recall_1: 0.9678 - val_accuracy: 0.9542 - val_f1_score: 0.3973 - val_loss: 0.1344 - val_precision_1: 0.9557 - val_recall_1: 0.9525
# Epoch 3/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9705 - f1_score: 0.4043 - loss: 0.1041 - precision_1: 0.9715 - recall_1: 0.9683 - val_accuracy: 0.9633 - val_f1_score: 0.2504 - val_loss: 0.1341 - val_precision_1: 0.9649 - val_recall_1: 0.9633
# Epoch 4/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.9681 - f1_score: 0.4089 - loss: 0.1008 - precision_1: 0.9716 - recall_1: 0.9668 - val_accuracy: 0.9617 - val_f1_score: 0.2465 - val_loss: 0.1188 - val_precision_1: 0.9665 - val_recall_1: 0.9608
# Epoch 5/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9730 - f1_score: 0.4295 - loss: 0.0982 - precision_1: 0.9757 - recall_1: 0.9718 - val_accuracy: 0.9642 - val_f1_score: 0.2862 - val_loss: 0.1449 - val_precision_1: 0.9650 - val_recall_1: 0.9642
# Epoch 6/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9730 - f1_score: 0.4086 - loss: 0.0837 - precision_1: 0.9741 - recall_1: 0.9715 - val_accuracy: 0.9683 - val_f1_score: 0.4032 - val_loss: 0.1066 - val_precision_1: 0.9699 - val_recall_1: 0.9667
# Epoch 7/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9729 - f1_score: 0.4125 - loss: 0.0910 - precision_1: 0.9746 - recall_1: 0.9715 - val_accuracy: 0.9683 - val_f1_score: 0.4107 - val_loss: 0.0987 - val_precision_1: 0.9691 - val_recall_1: 0.9683
# Epoch 8/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9762 - f1_score: 0.4489 - loss: 0.0795 - precision_1: 0.9767 - recall_1: 0.9741 - val_accuracy: 0.9758 - val_f1_score: 0.5068 - val_loss: 0.1029 - val_precision_1: 0.9766 - val_recall_1: 0.9758
# Epoch 9/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9781 - f1_score: 0.4749 - loss: 0.0797 - precision_1: 0.9786 - recall_1: 0.9775 - val_accuracy: 0.9717 - val_f1_score: 0.4907 - val_loss: 0.1062 - val_precision_1: 0.9717 - val_recall_1: 0.9717
# Epoch 10/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9763 - f1_score: 0.4457 - loss: 0.0845 - precision_1: 0.9771 - recall_1: 0.9741 - val_accuracy: 0.9733 - val_f1_score: 0.4524 - val_loss: 0.1024 - val_precision_1: 0.9733 - val_recall_1: 0.9733
# Epoch 11/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.9771 - f1_score: 0.4745 - loss: 0.0784 - precision_1: 0.9781 - recall_1: 0.9752 - val_accuracy: 0.9717 - val_f1_score: 0.4531 - val_loss: 0.1017 - val_precision_1: 0.9733 - val_recall_1: 0.9708
# Epoch 12/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 11s 17ms/step - accuracy: 0.9786 - f1_score: 0.4874 - loss: 0.0720 - precision_1: 0.9793 - recall_1: 0.9775 - val_accuracy: 0.9725 - val_f1_score: 0.4573 - val_loss: 0.0883 - val_precision_1: 0.9740 - val_recall_1: 0.9692
# Epoch 13/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9750 - f1_score: 0.4727 - loss: 0.0737 - precision_1: 0.9765 - recall_1: 0.9740 - val_accuracy: 0.9708 - val_f1_score: 0.4049 - val_loss: 0.1123 - val_precision_1: 0.9716 - val_recall_1: 0.9708
# Epoch 14/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.9763 - f1_score: 0.4861 - loss: 0.0776 - precision_1: 0.9767 - recall_1: 0.9754 - val_accuracy: 0.9767 - val_f1_score: 0.5370 - val_loss: 0.0853 - val_precision_1: 0.9783 - val_recall_1: 0.9750
# Epoch 15/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9747 - f1_score: 0.4770 - loss: 0.0756 - precision_1: 0.9759 - recall_1: 0.9731 - val_accuracy: 0.9725 - val_f1_score: 0.5166 - val_loss: 0.1007 - val_precision_1: 0.9741 - val_recall_1: 0.9700
# Epoch 16/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9806 - f1_score: 0.5071 - loss: 0.0685 - precision_1: 0.9815 - recall_1: 0.9800 - val_accuracy: 0.9675 - val_f1_score: 0.4228 - val_loss: 0.1360 - val_precision_1: 0.9707 - val_recall_1: 0.9658
# Epoch 17/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9800 - f1_score: 0.4769 - loss: 0.0685 - precision_1: 0.9817 - recall_1: 0.9785 - val_accuracy: 0.9692 - val_f1_score: 0.4568 - val_loss: 0.1057 - val_precision_1: 0.9691 - val_recall_1: 0.9675
# Epoch 18/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9779 - f1_score: 0.4987 - loss: 0.0788 - precision_1: 0.9790 - recall_1: 0.9768 - val_accuracy: 0.9725 - val_f1_score: 0.5150 - val_loss: 0.0934 - val_precision_1: 0.9732 - val_recall_1: 0.9683
# Epoch 19/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9800 - f1_score: 0.5163 - loss: 0.0624 - precision_1: 0.9816 - recall_1: 0.9787 - val_accuracy: 0.9692 - val_f1_score: 0.3935 - val_loss: 0.0930 - val_precision_1: 0.9708 - val_recall_1: 0.9683
# Epoch 20/20
# 425/425 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9780 - f1_score: 0.4977 - loss: 0.0706 - precision_1: 0.9789 - recall_1: 0.9769 - val_accuracy: 0.9783 - val_f1_score: 0.5182 - val_loss: 0.0827 - val_precision_1: 0.9791 - val_recall_1: 0.9783

# %%
df_result=pd.DataFrame(result.history)

# %%
df_result
# Out:
#     accuracy                                           f1_score      loss  \
# 0   0.969559  (tf.Tensor(0.5203252, shape=(), dtype=float32)...  0.122614
# 1   0.967941  (tf.Tensor(0.34328356, shape=(), dtype=float32...  0.107418
# 2   0.970588  (tf.Tensor(0.49253723, shape=(), dtype=float32...  0.105445
# 3   0.969559  (tf.Tensor(0.4892086, shape=(), dtype=float32)...  0.098145
# 4   0.973235  (tf.Tensor(0.5384615, shape=(), dtype=float32)...  0.095587
# 5   0.971765  (tf.Tensor(0.4776119, shape=(), dtype=float32)...  0.096739
# 6   0.972794  (tf.Tensor(0.5343511, shape=(), dtype=float32)...  0.092166
# 7   0.974412  (tf.Tensor(0.59999996, shape=(), dtype=float32...  0.086376
# 8   0.974265  (tf.Tensor(0.63829786, shape=(), dtype=float32...  0.083615
# 9   0.973088  (tf.Tensor(0.62499994, shape=(), dtype=float32...  0.088412
# 10  0.974118  (tf.Tensor(0.63945574, shape=(), dtype=float32...  0.090273
# 11  0.975735  (tf.Tensor(0.642857, shape=(), dtype=float32),...  0.081642
# 12  0.976029  (tf.Tensor(0.67549664, shape=(), dtype=float32...  0.077504
# 13  0.975588  (tf.Tensor(0.6086956, shape=(), dtype=float32)...  0.076776
# 14  0.978382  (tf.Tensor(0.7123287, shape=(), dtype=float32)...  0.073109
# 15  0.978529  (tf.Tensor(0.76, shape=(), dtype=float32), tf....  0.073462
# 16  0.978235  (tf.Tensor(0.6999999, shape=(), dtype=float32)...  0.076608
# 17  0.977353  (tf.Tensor(0.6712328, shape=(), dtype=float32)...  0.080554
# 18  0.980147  (tf.Tensor(0.7549668, shape=(), dtype=float32)...  0.069306
# 19  0.978382  (tf.Tensor(0.73825496, shape=(), dtype=float32...  0.070270
#
#     precision_1  recall_1  val_accuracy  \
# 0      0.971209  0.967353      0.970833
# 1      0.969465  0.966471      0.954167
# 2      0.971686  0.968971      0.963333
# 3      0.971808  0.968235      0.961667
# 4      0.974779  0.971912      0.964167
# 5      0.973013  0.970294      0.968333
# 6      0.974484  0.971618      0.968333
# 7      0.975243  0.973235      0.975833
# 8      0.975103  0.973382      0.971667
# 9      0.974631  0.971765      0.973333
# 10     0.975218  0.972206      0.971667
# 11     0.977005  0.974706      0.972500
# 12     0.977447  0.975147      0.970833
# 13     0.976432  0.974853      0.976667
# 14     0.979068  0.976765      0.972500
# 15     0.979523  0.977794      0.967500
# 16     0.979505  0.976912      0.969167
# 17     0.978338  0.976324      0.972500
# 18     0.981140  0.979265      0.969167
# 19     0.979228  0.977500      0.978333
#
#                                          val_f1_score  val_loss  \
# 0   (tf.Tensor(0.2352941, shape=(), dtype=float32)...  0.110591
# 1   (tf.Tensor(0.47999996, shape=(), dtype=float32...  0.134420
# 2   (tf.Tensor(0.2352941, shape=(), dtype=float32)...  0.134111
# 3   (tf.Tensor(0.31578946, shape=(), dtype=float32...  0.118752
# 4   (tf.Tensor(0.2352941, shape=(), dtype=float32)...  0.144915
# 5   (tf.Tensor(0.2352941, shape=(), dtype=float32)...  0.106627
# 6   (tf.Tensor(0.5925926, shape=(), dtype=float32)...  0.098663
# 7   (tf.Tensor(0.71999997, shape=(), dtype=float32...  0.102932
# 8   (tf.Tensor(0.66666657, shape=(), dtype=float32...  0.106173
# 9   (tf.Tensor(0.71999997, shape=(), dtype=float32...  0.102380
# 10  (tf.Tensor(0.6153846, shape=(), dtype=float32)...  0.101671
# 11  (tf.Tensor(0.6666666, shape=(), dtype=float32)...  0.088348
# 12  (tf.Tensor(0.33333328, shape=(), dtype=float32...  0.112309
# 13  (tf.Tensor(0.70967734, shape=(), dtype=float32...  0.085300
# 14  (tf.Tensor(0.6470588, shape=(), dtype=float32)...  0.100652
# 15  (tf.Tensor(0.2352941, shape=(), dtype=float32)...  0.135999
# 16  (tf.Tensor(0.6666666, shape=(), dtype=float32)...  0.105696
# 17  (tf.Tensor(0.7692307, shape=(), dtype=float32)...  0.093384
# 18  (tf.Tensor(0.49999997, shape=(), dtype=float32...  0.092970
# 19  (tf.Tensor(0.8275862, shape=(), dtype=float32)...  0.082670
#
#     val_precision_1  val_recall_1
# 0          0.972385      0.968333
# 1          0.955686      0.952500
# 2          0.964942      0.963333
# 3          0.966471      0.960833
# 4          0.964971      0.964167
# 5          0.969900      0.966667
# 6          0.969141      0.968333
# 7          0.976647      0.975833
# 8          0.971667      0.971667
# 9          0.973333      0.973333
# 10         0.973266      0.970833
# 11         0.974037      0.969167
# 12         0.971643      0.970833
# 13         0.978261      0.975000
# 14         0.974059      0.970000
# 15         0.970687      0.965833
# 16         0.969115      0.967500
# 17         0.973199      0.968333
# 18         0.970760      0.968333
# 19         0.979149      0.978333

# %%
#	accuracy	f1_score	loss	precision_1	recall_1	val_accuracy	val_f1_score	val_loss	val_precision_1	val_recall_1

# %%
import pickle
with open("scaler.pkl","wb") as f1:
  pickle.dump(scaler,f1)

from tensorflow.keras.models import save_model

# Save the model in HDF5 format (.h5)
model.save("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
